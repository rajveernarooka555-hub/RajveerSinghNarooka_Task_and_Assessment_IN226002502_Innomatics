# %%
# ==========================================
# LOGIC BUILDING QUESTION -
# ==========================================

# ------------------------------------------
# TASK 1: User Login Check
# ------------------------------------------
print("--- Task 1: Login Check ---")
if_username = "admin"
if_password = "1234"
username = input("Enter Username: ")
password = input("Enter Password: ")
if username == if_username and password == if_password:
    print("Login Successfull")
else:
    print("Invalid Credentials")
print("\n")
# Out:
# --- Task 1: Login Check ---
# Enter Username: admin
# Enter Password: 1234
# Login Successfull

# %%
# ------------------------------------------
# TASK 2: Pass/Fail Analyser
# ------------------------------------------
print("--- Task 2: Pass/Fail Analyzer ---")
def analyze_results(marks):
    pass_count = 0
    fail_count = 0
    print("\nStudent Results Analysis")
    print("-------------------------------")
    for index , mark in enumerate (marks,start=1):
        if mark >= 50:
            result = "PASS"
            pass_count += 1
        else:
            result = "FAIL"
            fail_count += 1
        print(f"Student {index}: Marks = {mark} --> {result}")
    print("\nSummary")
    print("------------------------")
    print(f"Marks: {marks}")
    print(f"Total Students:", len (marks))
    print(f"Total Passed: {pass_count}")
    print(f"Total Failed: {fail_count}")
    print("\n")

marks = [45, 78, 90, 33, 60]
analyze_results(marks)
# Out:
# --- Task 2: Pass/Fail Analyzer ---
#
# Student Results Analysis
# -------------------------------
# Student 1: Marks = 45 --> FAIL
# Student 2: Marks = 78 --> PASS
# Student 3: Marks = 90 --> PASS
# Student 4: Marks = 33 --> FAIL
# Student 5: Marks = 60 --> PASS
#
# Summary
# ------------------------
# Marks: [45, 78, 90, 33, 60]
# Total Students: 5
# Total Passed: 3
# Total Failed: 2

# %%
# ------------------------------------------
# TASK 3: Simple Data Cleaner
# ------------------------------------------
print("--- Task 3: Data Cleaner ---")
names = [" Alice ", "bob", " CHARLIE "]
# List comprehension for resue cleaning causes speed up!
cleaned_names = [name.strip().lower() for name in names]
print(f"Original: {names}")
print(f"Cleaned: {cleaned_names}")
print("\n")
# Out:
# --- Task 3: Data Cleaner ---
# Original: [' Alice ', 'bob', ' CHARLIE ']
# Cleaned: ['alice', 'bob', 'charlie']

# %%
# ------------------------------------------
# TASK 4: Length of Messaging Analysis
# ------------------------------------------
print("--- Task 4: Message Length Analyser ---")
messages = ["Hi", "Welcome to the platform", "OK"]
for msg in messages:
    length = len(msg)
    status = "FLAGGED" if length > 10 else "OK"
    print(f"Message: '{msg}' | Length: {length} -{'->' if status else ' Unknown '}-")
print("\n")
# Out:
# --- Task 4: Message Length Analyser ---
# Message: 'Hi' | Length: 2 -->-
# Message: 'Welcome to the platform' | Length: 23 -->-
# Message: 'OK' | Length: 2 -->-

# %%
# ------------------------------------------
# Task 5: Error Message Detection
# ------------------------------------------
print("--- Task 5: Error Log Monitor ---")
logs=["INFO", "ERROR","WARNING","ERROR"]
# Using built-in 'count' method for optimization and cleanliness.
total_errors = logs.count("ERROR")
print(f"Logs: {logs}")
print(f"Total 'ERROR' counts: {total_errors}")
print("\n")
# Out:
# --- Task 5: Error Log Monitor ---
# Logs: ['INFO', 'ERROR', 'WARNING', 'ERROR']
# Total 'ERROR' counts: 2
